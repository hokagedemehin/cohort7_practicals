# %% [markdown]
# # Book Recommendations Dataset

# %% [markdown]
# This notebook uses the [Book Recommendations](https://www.kaggle.com/arashnic/book-recommendation-dataset) dataset available on Kaggle.

# %% [markdown]
# ## Imports

# %%
# TODO: Import any other modules you need
import pandas as pd
import numpy as np
from pathlib import Path, PurePath

Path("__file__").parent.resolve() / "archive/Books.csv"
# PurePath.parent(Path("__file__").parent.resolve)
# PurePath.joinpath(Path("__file__").parent, "/acives")
# Out:
# WindowsPath('C:/Users/User/Documents/GitHub/cohort7_practicals/3_Introduction_to_Pandas/archive/Books.csv')

# %%
# TODO: Read Books.csv, Ratings.csv and Users.csv into similary named dataframes
ratings = pd.read_csv(Path("__file__").parent.resolve() / "archive/Ratings.csv")
users = pd.read_csv(Path("__file__").parent.resolve() / "archive/Users.csv")
books = pd.read_csv(Path("__file__").parent.resolve() / "archive/Books.csv")
# Out:
# C:\Users\User\.virtualenvs\3_Introduction_to_Pandas-OKSNLkmC\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
books['new']=books['Book-Title'].map(type) != str

# %%
books[books['Publisher'].map(type) != str ].index.tolist()
# Out:
# [128890, 129037]

# %%
books[books['Book-Title']==False].index.tolist()
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_26780/2318486388.py", line 1
#     books[books['Book-Title']===False].index.tolist()
#                                ^
# SyntaxError: invalid syntax

# %%
# a function that will run all the values in a column and give the index or the row that has the different dtype that is making the column an object. work on this tomorrow

# %%
a= books['Book-Title'].unique()
sorted(a)
# Out:
# [' A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)',
#  ' Always Have Popsicles',
#  " Apple Magic (The Collector's series)",
#  ' Ask Lily (Young Women of Faith: Lily Series, Book 5)',
#  ' Beyond IBM: Leadership Marketing and Finance for the 1990s',
#  ' Clifford Visita El Hospital (Clifford El Gran Perro Colorado)',
#  ' Dark Justice',
#  ' Deceived',
#  ' Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth',
#  ' Final Fantasy Anthology: Official Strategy Guide (Brady Games)',
#  ' Flight of Fancy: American Heiresses (Zebra Ballad Romance)',
#  ' Garfield Bigger and Better (Garfield (Numbered Paperback))',
#  " God's Little Promise Book",
#  ' Good Wives: Image and Reality in the Lives of Women in Northern New England, 1650-1750',
#  ' Goosebumps Monster Edition 1: Welcome to Dead House, Stay Out of the Basement, and Say Cheese and Die!',
#  ' Harry Potter and the Bible: The Menace Behind the Magick (And the Bible Series)',
#  ' Highland Desire (Zebra Splendor Historical Romances)',
#  ' Hiking the California Coastal Trail: Oregon to Monterey',
#  ' It Takes Two',
#  ' LA Gallinita Roja/the Little Red Hen',
#  ' Little Comic Shop of Horrors (Give Yourself Goosebumps, Book 17)',
#  ' Microsoft Application Architecture For Microsoft .net: Designing Application (Pro-Other)',
#  ' Murder of a Sleeping Beauty (Scumble River Mysteries (Paperback))',
#  ' Mystery Mile',
#  ' Nonbook Materials: The Organization of Integrated Collections',
#  " Pokemon: The Official Collector's Sticker Book",
#  ' Q-Space (Star Trek The Next Generation, Book 47)',
#  ' Q-Zone (Star Trek The Next Generation, Book 48)',
#  ' Stories of an Imaginary Childhood',
#  ' Summonings: Books of Magic, Vol. 2',
#  ' Tales of Terror and Suspense',
#  ' The Secret of the Old Clock (Nancy Drew, Book 1)',
#  " The Tender Commandments : Reflections on the Father's Love",
#  ' The Town Cats and Other Tales',
#  ' This Place Has No Atmosphere (Laurel-Leaf Books)',
#  ' Tough Loser',
#  ' Travel Companion Chile and Easter Island (Travel Companion)',
#  ' Twenty Thousand Leagues Under the Sea (Illustrated Classics)',
#  ' Weird News Stories',
#  ' Zap!: Science Fair Surprise! (Abracadabra!, Book 5)',
#  ' the Devil Will Drag You Under',
#  '!%@ (A Nutshell handbook)',
#  '!Arriba! Comunicacion y cultura',
#  '!Trato hecho!: Spanish for Real Life, Combined Edition',
#  '!Yo!',
#  '$14 In The Bank (Cathy Collection)',
#  '$30 Film School',
#  '$Weet Deal$',
#  "$oft Money: The True Power in Our Nation's Capital",
#  "' Allo 'Allo: the War Diaries of Rene Artois",
#  "' L' Is for Lawless",
#  "' Mein verwundetes Herz'. Das Leben der Lilli Jahn 1900 - 1944.",
#  "' Sehr geehrtes Arschloch.' Briefe an den RegierungsprÃ?Â¤sidenten.",
#  "' Sie belieben wohl zu scherzen, Mr. Feynman.'. Abenteuer eines neugierigen Physikers.",
#  "' Small g'. Eine Sommeridylle.",
#  "' Til the Fat Lady Sings",
#  "' Tis",
#  "' Warum sagen Sie nicht, was Sie meinen?'",
#  "'48",
#  "'A Hell of a Place to Lose a Cow': An American Hitchhiking Odyssey",
#  "'California Historical Landmarks'",
#  "'Das geht alles von Ihrer Zeit ab.'",
#  "'Eine gute Frau hat keinen Kopf'. EuropÃ?Â¤ische SprichwÃ?Â¶rter Ã?Â¼ber Frauen.",
#  "'G' Is for Grafton : The World of Kinsey Millhone",
#  "'Gentlemen Prefer Blondes' 'but Gentlemen Marry Brunettes'",
#  "'Great Speeches for Criticism and Analysis'",
#  "'Isms: a dictionary of words ending in -ism, -ology, and -phobia,: With some similar terms, arranged in subject order",
#  "'Mater Biscuit : A Homegrown Novel",
#  "'Mit Verlaub, Sie sind ein Arschloch.' Joschkas schÃ?Â¤rfste SprÃ?Â¼che.",
#  "'N SYNC: TEARIN' UP THE CHARTS",
#  "'N Sync",
#  "'N Sync With JC",
#  "'N Sync With Justin",
#  "'N Sync: Tearing Up Our Hearts",
#  "'Now What Are You Up To, Herman?'",
#  "'O Au No Keia: Voices from Hawai'I's Mahu and Transgender Communities",
#  "'Romance of Paula Vaughn'",
#  "'Round the Corner (Sister Circle)",
#  "'Salem's Lot",
#  "'Scope Out Your Life: What Your Sign Says About You (All about You (Scholastic))",
#  "'The Moon by Whale Light: And Other Adventures Among Bats, Penguins, Crocodilians, and Whales",
#  "'Til Death Do Us Part",
#  "'Til There Was You",
#  "'Til There Was You (Special Edition, No 576)",
#  "'Til We Meet Again (The Circle) (Silhouette Shadows, No 60)",
#  "'Tis Herself : A Memoir",
#  "'Tis The Season (Christmas Anthology): Under the Mistletoe/A Baby for Christmas/Christmas Angel/Home for Christmas",
#  "'Tis The Season (Harlequin Historical Series, No. 583)",
#  "'Tis The Season (Harlequin Temptation, No 278)",
#  "'Tis The Season (The Daddy School) (Superromance, 952)",
#  "'Tis the Season to Be Crabby (Festive Peanuts)",
#  "'Tis: A Memoir",
#  "'Twas The Night (Harlequin Desire No 684)",
#  "'Twas the Night Before Christmas",
#  "'Webster's New Business Writer's Guide (Webster's Dictionary Series)",
#  "'n Hollandse stadsguerrilla: Terugblik op de Rode Jeugd",
#  "'night, Mother : A Play (Mermaid Dramabook)",
#  "'til the Real Thing Comes Along",
#  '(George)',
#  "(Quinn's Way (Harlequin American Romance, No. 558)",
#  '(Un)arranged Marriage',
#  '* * *: A Novel',
#  '--Olivetti, Moulinex, Chaffoteaux et Maury (Quaderns crema. Narrativa)',
#  '--Und morgen die ganze Welt?: Rechstextreme Publizistik in Westeuropa',
#  '--fast ein Meisterwerk: Die Welt der Musik in Anekdoten : eine heitere Musik-Soziologie',
#  '--men i hvert fald i live',
#  '--y los 40 ladrones (ColecciÃ³n FÃ¡bula)',
#  '... And for Starters',
#  '... steigen aus... maschine brennt... 10 Fliegergeschichten.',
#  '... vol ... Ã\xa0 bord ... du.Concordia (Her Les Aventures de Michel Labre)',
#  '... wenn du es nicht lassen kannst.',
#  '...AND THE HORSE HE RODE IN ON : THE PEOPLE V. KENNETH STARR',
#  '...And Ladies of the Club',
#  '...And Now Miguel',
#  '...And The FAT Came Back',
#  '...Sacrifice of Angels:  The Dominion War Book 4 (Star Trek Deep Space Nine)',
#  '...and Conflict (Sugar Secrets S.)',
#  '.44',
#  '.44 (Leisure Western)',
#  '.Hack: //Legend of the Twilight, Vol. 1',
#  '.Hack: //Legend of the Twilight, Vol. 2',
#  '.NET Framework Essentials, 3rd Edition',
#  '006781: Bk.1 Gags De Boule Et Bil',
#  '007 El Mundo Nunca Es Suficiente',
#  '01-01-00: A Novel of the Millennium',
#  '01-01-00: The Novel of the Millennium',
#  '03 NODDY AND HIS CAR',
#  '0373953194 Christmas Stories 1993',
#  '06 Henry The Green Engine',
#  '08/15 Heute',
#  "09/11 8:48 am: Documenting America's Greatest Tragedy",
#  '1 + 2=4: Das Gigelchen geht in die Schule',
#  '1 2 3 Board Book',
#  '1 2 3 Draw Cars, Trucks, and Other Vehicles: A Step-By-Step Guide (1-2-3 Draw)',
#  '1 GENERATION AFTER',
#  '1 Mans Homestead (Illus)',
#  '1 Pot Meals',
#  '1 RAGGED RIDGE ROAD',
#  '1 World',
#  '1 x Jenseits, einfache Fahrt. Chili.',
#  '1+1+1 Une RÃ?Â©volution',
#  '1, 2, 3',
#  '1, 2, 3, Music!',
#  '1, 2, 3-- The Toddler Years: A Practical Guide for Parents and Caregivers',
#  '1, 2, 3: NURSERY BOARD BOOKS (Nursery Board Books)',
#  '1,000 Makers of the Millennium: The Men and Women Who Have Shaped the Last 1,000 Years',
#  '1,000 Marbles: A Little Something About Precious Time',
#  '1,000 More Jokes for Kids',
#  '1,000 Nursing Tips and Timesavers: Quick and Easy Tips for Improving Patient Care',
#  '1,000 Places to See Before You Die',
#  '1,000 Vegetarian Recipes',
#  '1,000 Years, 1,000 People: Ranking the Men and Women Who Shaped the Millennium',
#  '1,000 beautiful house plants and how to grow them',
#  '1,000,001 Things That Make You Crabby: The Official Checklist for Complainers, Ranters, Ravers and Bellyachers, and Everybody Else',
#  '1,001 Advertising Cuts from the Twenties and Thirties (Dover Pictorial Archive Series)',
#  '1,001 Computer Hints &amp; Tips: An A-To-Z Guide to Making the Most of Your Computer and the Internet',
#  '1,001 Facts Somebody Screwed Up',
#  '1,001 Great Gifts',
#  '1,001 Great Jokes/from the Delightfully Droll to the Truly Tasteless',
#  '1,001 Great Pet Jokes',
#  '1,001 Great Pick-Up Lines',
#  '1,001 Health Tips',
#  '1,001 Health-Care Questions Women Ask',
#  '1,001 Home Health Remedies for Seniors',
#  '1,001 Ideas for Science Projects',
#  '1,001 Low-Fat Vegetarian Recipes, 2nd ed.',
#  '1,001 Old-Time Garden Tips: Timeless Bits of Wisdom on How to Grow Everything Organically, from the Good Old Days When Everyone Did',
#  '1,001 Perfectly Legal Ways to Get Exactly What You Want, When You Want It, Every Time',
#  '1,001 Things Everyone Should Know About American History',
#  "1,001 Things to Do When There's Nothing to Do",
#  '1,001 Ways to Keep Customers Coming Back: Wow Ideas That Make Customers Happy and Will Increase Your Bottom Line',
#  '1,001 Ways to Save the Planet',
#  '1,003 Great Things About America',
#  '1,003 Great Things About Friends',
#  '1,003 Great Things About Getting Older',
#  '1,003 Great Things About Kids',
#  '1,003 Great Things About Teachers',
#  '1,2,3 To the Zoo: A Counting Book',
#  '1,337 Spot Illustrations of the Twenties and Thirties (Dover Pictorial Archive)',
#  '1,401 Even More Things That P*Ss Me Off',
#  '1,401 More Things That P*Ss Me Off',
#  '1,410 Quintessential Quizzes',
#  '1,440 Reasons To Quit Smoking : One for Every Minute of the Day...and Night',
#  '1,911 Best Things Anybody Ever Said',
#  '1-2-3',
#  '1-2-3 Draw Dinosaurs and Other Prehistoric Animals (123 Draw)',
#  '1-2-3 Draw Knights Castles &amp; Dragons: A Step by Step Guide (1-2-3 Draw)',
#  '1-2-3 Draw Pets and Farm Animals: A Step by Step Guide (123 Draw)',
#  '1-2-3 Draw Wild Animals: A Step by Step Guide (123 Draw)',
#  '1-2-3 Magic : Effective Discipline for Children 2-12',
#  '1-2-3 Magic: Effective Discipline for Children 2-12',
#  "1-2-3 Push! (The Little Dinosaurs' Adventures)",
#  '1-4-3 Means I Love You',
#  '1-800-Am-I-Nuts?',
#  '1-900-Dead',
#  '10 American History Plays for the Classroom (Grades 4-8)',
#  "10 Bad Choices That Ruin Black Women's Lives",
#  "10 Basic Steps Toward Christian Maturity (Leader's Guide)",
#  '10 Commandments Of Dating',
#  '10 Days to Faster Reading',
#  '10 Dumbest Mistakes Smart People Make and How To Avoid Them : Simple and Sure Techniques for Gaining Greater Control of Your Life',
#  '10 Feet Tall and Bulletproof',
#  '10 Gebote fÃ?Â¼r anspruchsvolle Frauen.',
#  '10 Keys for Unlocking the Bible: Treasures That Will Change Your Life',
#  '10 LITTLE INDIANS',
#  '10 Lb Penalty',
#  '10 Lb. Penalty',
#  '10 Minute Guide to Excel 4',
#  '10 Minute Guide to Excel 97 (10 Minute Guides (Computer Books))',
#  '10 Minute Guide to HTML 3.2',
#  '10 Minute Guide to Html',
#  '10 Minute Guide to Html 4.0 (Ten Minute Guide to...)',
#  '10 Minute Guide to Html Style Sheets (Ten Minute Guide Series)',
#  '10 Minute Guide to Lotus Notes Mail 4.6 (Ten Minute Guide to...)',
#  '10 Minute Guide to Norton Desktop for Windows',
#  '10 Minute Guide to PC Computing (Ten Minute Guide to...)',
#  '10 Minute Guide to Paying for Grad School (10 Minute Guides)',
#  '10 Minute Guide to Windows 3.1 (10 Minute Guide Series)',
#  '10 Minute Guide to Windows 95',
#  '10 Minute Marketing - A Daily Routine for Success (Book, Video, Cassette, &amp; Disk/Windows)',
#  '10 Minutes Till Bedtime',
#  '10 Minutue Guide to WordPerfect for Windows',
#  '10 Most Common Mistakes Good Parents Make: And How to Avoid Them',
#  '10 Natural Laws of Successful Time and Life Management',
#  "10 Of Today's Most Innovative Churches: What They're Doing, How They're Doing It and How You Can Apply Their Ideas in Your Church",
#  "10 Principles for Spiritual Parenting: Nurturing Your Child's Soul",
#  '10 Real SATs, Third Edition',
#  '10 Real Sats (Serial)',
#  '10 Reasons to Abolish the Imf &amp; World Bank (Open Media Pamphlet Series)',
#  '10 Relatos Fantasticos',
#  '10 Secrets for Success and Inner Peace',
#  '10 Steps in Writing the Research Paper (10 Steps in Writing the Research Paper, 5th ed)',
#  '10 Steps to Home Ownership: A Workbook for First-Time Buyers',
#  '10 Stupid Things Women Do to Mess Up Their Lives',
#  '10 Things I Hate About You',
#  '10 Things You Should Know About Dinosaurs (10 Things You Should Know series)',
#  '10 Years of Matt',
#  '10 critical keys for highly effective Mormon families',
#  '10 steps in writing the research paper,',
#  '10, 000 Dreams Interpreted',
#  '10,000 Answers: The Ultimate Trivia Encyclopedia',
#  '10,000 Dreams Interpreted',
#  "10,000 Dreams Interpreted or What's in a Dream",
#  '10,000 Dreams Interpreted: A Complete Guide to the Meaning of Your Dreams',
#  '10,000 Garden Questions Answered by 20 Experts',
#  '10,000 Garden Questions: Answered by 20 Experts',
#  '10,000 Names for Your Baby',
#  '10,000 Things to Praise God for',
#  '10,000 Ways to Say I Love You: The Biggest Collection of Romantic Ideas Ever Gathered in One Place',
#  '10,000 dreams interpreted: A dictionary of dreams',
#  '10-20-30 Minutes to Quilt (Sewing with Nancy)',
#  '10-Minute Card Games',
#  '10-Minute Decorating: 176 Fabulous Shortcuts with Style',
#  '10-Minute Scrapbook Pages: Hundreds of Easy, Innovative Designs',
#  '100 Astounding Little Alien Stories',
#  '100 Banned Books: Censorship Histories of World Literature',
#  '100 Best Denver Area &amp; Front Range Day Hikes',
#  '100 Best Family Resorts in North America: 100 Quality Resorts With Leisure Activities for Children and Adults (The 100 Best Resorts)',
#  '100 Best Honeymoon Resorts of the World (The 100 Best Resorts Series)',
#  '100 Best Romantic Resorts of the World',
#  '100 Best TV Commercials: And Why They Worked',
#  '100 Best-Loved Poems (Dover Thrift Editions)',
#  '100 Bible Quiz Activities for Church School Classes',
#  '100 Billion Suns: The Birth, Life, and Death of the Stars',
#  '100 Birds and How They Got Their Names',
#  '100 Books for Girls to Grow On',
#  '100 Carols for Choirs',
#  '100 Christian Women Who Changed the Twentieth Century',
#  '100 Cross-Stitch Christmas Ornaments',
#  '100 Dastardly Little Detective Stories',
#  '100 Days in the Jungle',
#  '100 Days of Fun at School',
#  '100 Excuses for Kids',
#  '100 Favorite Flowering Shrubs (The 100 Favorite Series)',
#  '100 Flowers and How They Got Their Names',
#  '100 Gedichte ohne Vaterland (Wagenbachs TaschenbÃ¼cherei ; 44)',
#  '100 Geordie Jokes',
#  '100 Ghastly Little Ghost Stories',
#  '100 Glimpses into China',
#  '100 Great Archaeological Discoveries',
#  '100 Great Fantasy Short Short Stories',
#  '100 Great Fantasy Short, Short Stories',
#  '100 Great Kings Queens &amp; Rules',
#  '100 Great Natural Remedies: Using Healing Plants at Home',
#  '100 Great Operas and Their Stories',
#  '100 Great Problems of Elementary Mathematics: Their History and Solution',
#  '100 Great Science Fiction Short Short Stories',
#  '100 Great Soup, Stew &amp; Chili Recipes',
#  '100 Greatest Women',
#  '100 Hair Raising Little Horror Stories',
#  '100 Hikes in Colorado (100 Hikes Series)',
#  '100 Hikes in the Alps',
#  '100 Hilarious Little Howlers',
#  '100 Local Heroes',
#  '100 Magic Tricks',
#  '100 Malicious Little Mysteries',
#  '100 Monologues: An Audition Sourcebook from New Dramatists',
#  '100 Most Important Women of the 20th Century',
#  "100 One-Night Reads: A Book Lover's Guide",
#  '100 Plants for Quick Growing Gardens',
#  '100 Poems Without a Country (German Poetry)',
#  '100 Poems by 100 Poets: An Anthology',
#  '100 Questions Every First-Time Home Buyer Should Ask : With Answers from Top Brokers from Around the Country',
#  '100 Questions Every First-Time Home Buyer Should Ask: With Answers from Top Brokers from Around the Country',
#  '100 Questions You Should Ask About Your Personal Finances: And the Answers You Need to Help You Save, Invest, and Grow Your Money',
#  '100 Questions and Answers: Dinosaurs (100 Questions and Answers Series)',
#  '100 Relationships That Shaped World History',
#  "100 Secrets of the Smokies: A Guide to the Best Undiscovered Places in the Great Smoky Mountains Area (The Savvy Traveler's Guide)",
#  '100 Selected Poems',
#  '100 Selected Poems by E. E. Cummings',
#  '100 Selected Stories (Wordsworth Classics)',
#  '100 Simple Secrets of Great Relationships : What Scientists Have Learned and How You Can Use It',
#  '100 Simple Secrets of Healthy People : What Scientists Have Learned and How You Can Use it (100 Simple Secrets)',
#  '100 Strokes of the Brush Before Bed (Black Cat Series)',
#  '100 TOP PSYCHICS IN AMERICA: THEIR STORIES SPECIALTIES &amp; HOW TO CONTACT THEM',
#  '100 Things Every Writer Needs to Know',
#  "100 Things I'm Not Going to Do Now That I'm over 50",
#  '100 Things to Always Remember and One Thing to Never Forget (Self-Help)',
#  "100 Things to Do Before You Die: Travel Events You Just Can't Miss",
#  '100 Thoughts That Lead to Happiness',
#  '100 Treasures of Buckingham Palace',
#  '100 Voices: Words That Shaped Our Souls Wisdom to Guide Our Future',
#  '100 Walks in Tasmania',
#  '100 Ways of Seeing an Unequal World',
#  '100 Ways to Attract Angels',
#  '100 Ways to Enhance Self-Concept in the Classroom: A Handbook for Teachers and Parents (Prentice-Hall Curriculum and Teaching Series)',
#  '100 Ways to Keep Your Soul Alive (Living Deeply and Fully Every Day)',
#  '100 Ways to Keep Your Soul Alive : Living Deeply and Fully Every Day',
#  '100 Ways to Motivate Yourself',
#  '100 Ways to Motivate Yourself: Change Your Life Forever',
#  '100 Ways to Overcome Depression',
#  '100 Weekend Cross-Stitch Gifts',
#  '100 Words About Animals',
#  '100 Words Every High School Graduate Should Know',
#  '100 Years of American Newspaper Comics: An Illustrated Encyclopedia',
#  '100 Years of Oz: A Century of Classic Images from the Wizard of Oz Collection of Willard Carroll',
#  '100 Years: 100 Stories',
#  '100 greatest golf courses--and then some',
#  '100 hikes in the North Cascades: Mt. Baker area, North Cascades NP, Ross Lake NRA, Pasayten Wilderness, Methow-Chelan',
#  '100 hikes in the South Cascades and Olympics',
#  '100 op de schaal van lief: Gedichten &amp; liedteksten',
#  '100 years of the Wimbledon tennis championships',
#  '100% American',
#  '100% Chocolate',
#  '100% Hero (Spotlight)',
#  '100% True!',
#  '100.000 Kilometros Tras Los Ovnis (Los Jet De Plaza &amp; Janes)',
#  '1000 Crazy Jokes for Kids',
#  '1000 Dogs (Klotz)',
#  '1000 Facts About Space',
#  '1000 Facts About Wild Animals',
#  '1000 Facts About the Earth (1000 Facts about)',
#  '1000 Forbidden Pictures',
#  '1000 Gefahren. Die Insel der 1000 Gefahren.',
#  '1000 Gefahren. Die Juwelen von Nabooti.',
#  '1000 Gefahren. Die Spur des BÃ?Â¤ren. ( Ab 10 J.).',
#  '1000 Gefahren. Katastrophentag.',
#  '1000 Great Quilt Blocks (That Patchwork Place)',
#  '1000 Jokes for Kids of All Ages',
#  '1000 Knock Knock Jokes for Kids',
#  '1000 Most Challenging Words',
#  '1000 Paths to Zen',
#  '1000 Photo Icons',
#  '1000 Play Thinks: Puzzles, Paradoxes, Illusions &amp; Games',
#  '1000 Questions About Canada',
#  '1000 Questions and Answers',
#  '1000 Tattoos (Klotz)',
#  '1000 neue Dinge, die man bei Schwerelosigkeit tun kann.',
#  '10000 Dreams Interpreted',
#  '10000 Garden Questions Answered',
#  '1001 Activities for a Smarter Child',
#  '1001 Beauty Solutions: The Ultimate One-Step Adviser for Your Everyday Beauty Problems',
#  '1001 Brilliant Ways to Checkmate',
#  '1001 Cookie Recipes',
#  '1001 Four-Ingredient Recipes',
#  '1001 Free Goodies and Cheapies',
#  '1001 Hints &amp; Tips for Your Garden : An Indispensable Guide to Easier and More Effective Gardening',
#  '1001 Ideas to Create Retail Excitement',
#  '1001 More Ways to Be Romantic',
#  '1001 Muffins, Biscuits, Doughnuts, Pancakes, Waffles, Popovers, Fritters, Scones and Other Quick Breads',
#  '1001 Natural Remedies',
#  '1001 Oriental Recipes',
#  '1001 Pitfalls in French (1001 Pitfalls Series)',
#  '1001 Questions Answered About Earthquakes, Avalanches, Floods, and Other Natural Disasters',
#  '1001 Really Cool Web Sites',
#  '1001 Secrets for Windows Nt Registry',
#  '1001 Simple Ways to Lose Weight: Proven Tips for Losing Those Extra Pounds-- And Keeping Them of',
#  '1001 Spot Illustrations of the Lively Twenties (Dover Pictorial Archive Series)',
#  '1001 Texas Place Names',
#  '1001 Things Everyone Should Know About African American History',
#  '1001 Things Everyone Should Know About Irish-American History',
#  '1001 Things Everyone Should Know About Science',
#  "1001 Things Everyone Should Know About Women's History",
#  '1001 Things Everyone Should Know About the South',
#  '1001 Things Everyone Should Know About the Universe',
#  '1001 Things to Do With Your Kids',
#  '1001 Ways To Save Money . . . and Still Have a Dazzling Wedding',
#  '1001 Ways to Be Romantic',
#  '1001 Ways to Celebrate America',
#  '1001 Ways to Cut Your Expenses',
#  '1001 Ways to Energize Employees',
#  '1001 Ways to Reveal Your Personality',
#  '1001 Ways to Reward Employees',
#  '1001 Ways to Save Money ... and Still Have a Dazzling Wedding',
#  '1001 maximes de motivation',
#  '1001 pitfalls in Spanish,',
#  '1001 valuable things you can get free',
#  '1002 Ways to Waste Your Working Time',
#  '1008 Secrets of a Happy Marriage',
#  '101 Amazing Things about God',
#  '101 Back to School Jokes',
#  '101 Best Cheers: How to Be the Best Cheerleader Ever',
#  '101 Best Dot.Coms to Start: The Essential Sourcebook of Startup Wisdom, Financial Tips, and Inside Secrets for Building a Business on the Internet',
#  '101 Best Extra-Income Opportunities for Women',
#  '101 Best Family Card Games',
#  '101 Best Home-Based Businesses for Women',
#  '101 Bossy Cow Jokes',
#  '101 Bright Ideas: Esl Activities for All Ages',
#  '101 Bug Jokes',
#  '101 Business You Can',
#  '101 Cat and Dog Jokes',
#  '101 Common Therapeutic Blunders',
#  '101 Commonsense Rules for Making Things Happen: How to Make Plans and Implement Projects (How-To Guides)',
#  '101 Corporate Haiku',
#  '101 Cose De Vedere E Fare in Irlanda',
#  '101 Creepy Creature Jokes',
#  '101 Dalmatians',
#  '101 Dalmatians (Pictureback Books (Paperback))',
#  '101 Dalmatians (Sight &amp; Sound)',
#  '101 Dalmatians : Escape from De Vil Mansion',
#  '101 Dalmatians: Proud to Be a Pup',
#  '101 Dalmatians: What If Cruella De Vil was Your Lunch Lady?',
#  '101 Dalmations',
#  "101 Dalmations - Collector's Edition (Illustrated Classic)",
#  '101 Dinosaur Jokes',
#  '101 Do-It-Yourself Projects',
#  '101 Educational Conversations With Your 3rd Grader (101 Educational Conversations You Should Have With Your Child)',
#  '101 Essential Tips on Photography (101 Essential Tips)',
#  '101 Essential Tips on Video',
#  '101 Essential Tips: Aquarium Fish',
#  '101 Essential Tips: Baby Care',
#  '101 Essential Tips: Basic Gardening',
#  '101 Essential Tips: Basic Meditation',
#  '101 Essential Tips: Bonsai',
#  '101 Essential Tips: Chicken',
#  '101 Essential Tips: Cooking With Spices (101 Essential Tips)',
#  '101 Essential Tips: Healthy Living',
#  '101 Essential Tips: House Plants',
#  '101 Ethical Dilemmas',
#  '101 Experiments in the Philosophy of Everyday Life',
#  '101 Famous Poems',
#  '101 Favorite Cat Poems',
#  '101 Feng Shui Tips for Your Home',
#  '101 French Proverbs',
#  '101 Full-Size Quilt Blocks and Borders',
#  '101 Fun Things to Do on the Texas Coast',
#  '101 Funny Bunny Jokes',
#  '101 Great American Poems (Dover Thrift Editions)',
#  '101 Great Answers to the Toughest Interview Questions (3rd ed)',
#  '101 Great Answers to the the Toughest Financial Questions',
#  '101 Great Lowfat Mexican Dishes: Hot, Spicy &amp; Healthful',
#  '101 Great Mail-Order Businesses: The Very Best (And Most Profitable!) Mail-Order Businesses You Can Start With Little or No Money',
#  '101 Great Nature Experiments',
#  '101 Great Resumes',
#  '101 Great Science Experiments',
#  '101 Grunde Kein Ossi Zu Sein',
#  '101 Hamburger Jokes',
#  '101 Holiday Jokes',
#  '101 Hopelessly Hilarious Jokes',
#  '101 Inspirational Stories of the Rosary',
#  '101 Jr Book CL: Autob',
#  '101 Killer Apps for Your Pocket PC (101 Killer Apps)',
#  '101 Law Forms for Personal Use, Third Edition',
#  '101 Lies Men Tell Women -- And Why Women Believe Them',
#  '101 Marvelous Money-Making Ideas For Kids',
#  '101 Most Powerful Proverbs in the Bible (101 Most Powerful Series)',
#  '101 Most Powerful Verses in the Bible',
#  '101 Nights of Grrreat Sex',
#  '101 Nutty Nature Jokes',
#  '101 Outdoor Adventures: Great Things to Do Under the Sun (And the Stars)',
#  '101 Outer Space Jokes (101 Joke Book)',
#  '101 Perfect Chocolate Chip Cookies',
#  '101 Pet Jokes',
#  '101 Philosophy Problems',
#  '101 Poems Against War',
#  '101 Poems That Could Save Your Life : An Anthology of Emotional First Aid',
#  '101 Poems to Get You Through the Day (and Night)',
#  '101 President Jokes',
#  '101 Promises Worth Keeping (For Men Only)',
#  '101 Questions Children Ask about God (Questions Children Ask)',
#  '101 Questions Your Cat Would Ask Its Vet (If Your Cat Could Talk)',
#  '101 Questions Your Cat Would Ask Its Vet: If Your Cat Could Talk',
#  "101 Questions Your Cat Would Ask: What's Bothering Your Cat and How to Solve Its Problems",
#  '101 Questions Your Dog Would Ask Its Vet (If Your Dog Could Talk)',
#  '101 Questions and Answers on Buddhism',
#  '101 Questions and Answers on Islam',
#  '101 Quick Tips to Make Your Home Feel Sensesational',
#  '101 Quick Tips to Make Your Home Look Sensesational',
#  '101 Quick Tips to Make Your Home Smell Sensesational',
#  '101 Quick Tips to Make Your Home Sound Sensesational',
#  '101 Quick Tips to Make Your Home Taste Sensesational',
#  '101 Quizzlers (Mind Benders and Fun Facts Series)',
#  '101 Reasons Why Cats Make Great Kids',
#  '101 Reasons Why a Cat Is Better Than a Man',
#  '101 Reasons for Time-out in Kindergarten &amp; Preschool',
#  '101 Reasons to READ to Your Child',
#  '101 Reykjavik',
#  '101 ReykjavÃ\xadk: A Novel',
#  '101 Rock and Roll Jokes and Riddles',
#  '101 Safe Internet Sites for Kids',
#  '101 Salivations: For the Love of Dogs',
#  '101 School Cafeteria Jokes',
#  '101 School Jokes',
#  '101 Science Projects (Troll Teacher Idea Books)',
#  '101 Secrets A Cool Mom Knows',
#  '101 Shaggy Dog Stories',
#  '101 Silly Monster Jokes',
#  '101 Silly Summertime Jokes',
#  '101 Simple Ways to Be Good to Yourself: How to Discover Peace and Joy in Your Life',
#  '101 Spooky Halloween Jokes',
#  '101 Stressed Out',
#  '101 Super Sports Jokes',
#  '101 Survival Secrets: How to Make $1,000,000, Lose 100 Pounds, and Just Plain Live Happily',
#  '101 Tax Loopholes for the Middle Class',
#  '101 Telephone Jokes',
#  '101 Thanksgiving Knock-Knocks, Jokes, and Riddles',
#  "101 Things God Can't Do",
#  '101 Things Not to Say During Sex',
#  "101 Things You Can Do for Our Children's Future",
#  "101 Things You Don't Know About Science and No One Else Does Either",
#  '101 Things to Do With Your Computer (Usborne Computer Guides)',
#  '101 Things to Do With a Cake Mix',
#  '101 Things to Do in the Year 2000',
#  "101 Things to Do to Develop Your Child's Gifts and Talents/for Children Ages 3-6",
#  '101 Training Tips for Your Cat',
#  '101 Training Tips for Your Dog',
#  '101 Unuseless Japanese Inventions',
#  '101 Unuseless Japanese Inventions: The Art of Chindogu',
#  '101 Uses for This Book',
#  '101 Uses for a Bridesmaid Dress',
#  '101 Uses for a Dead Cat',
#  '101 Uses for a Lab',
#  '101 Uses for an Ex-Husband',
#  '101 Vacation Jokes',
#  '101 Valentine Jokes',
#  '101 Vegetarian Delights',
#  '101 Wacky Camping Jokes',
#  '101 Wacky Computer Jokes',
#  '101 Wacky Facts About Bugs and Spiders',
#  '101 Wacky Facts About Kids',
#  '101 Wacky Facts About Mummies',
#  '101 Wacky Facts About Snakes &amp; Reptiles',
#  '101 Wacky Kid Jokes',
#  '101 Wacky Sports Quotes',
#  '101 Wacky State Jokes',
#  '101 Ways To Boost Your Math Skills',
#  '101 Ways To Boost Your Science Skills',
#  '101 Ways Your Church Can Change the World: A Guide to Help Christians Express the Love of Christ to a Needy World',
#  '101 Ways to Avoid Reincarnation: Or Getting It Right the First Time',
#  '101 Ways to Avoid Spelling Traps',
#  '101 Ways to Be a Special Dad',
#  '101 Ways to Be a Special Mom',
#  '101 Ways to Bug Your Parents',
#  '101 Ways to Count Sheep: Or Holy Cow Not Another Sheep!',
#  '101 Ways to Date Your Mate',
#  '101 Ways to Do Better in School',
#  '101 Ways to Feed the Heart',
#  '101 Ways to Flirt: How to Get More Dates and Meet Your Mate',
#  '101 Ways to Get Away With Anything! (Malcolm in the Middle)',
#  "101 Ways to Get Straight A's (101 Ways)",
#  '101 Ways to Juice It!: Luscious Receipes and the Best and Most Comprehensive Guide to Fruit and Vegetable Juicing',
#  '101 Ways to Make Every Second Count: Time Management Tips and Techniques for More Success With Less Stress',
#  '101 Ways to Make Money at Home',
#  '101 Ways to Make Your Child Feel Special',
#  '101 Ways to Promote Your Web Site: Filled With Proven Internet Marketing Tips, Tools, Techniques, and Resources to Increase Your Web Site Traffic',
#  '101 Ways to Read with Speed and Understanding',
#  '101 Ways to Recession-Proof Your Career',
#  '101 Ways to Start Your Own Business',
#  '101 Ways to Win Homecoming Queen (Three of a Kind, No 6)',
#  '101 Ways to Your Husbands Heart/Wifes Heart',
#  '101 Ways/Meet MR Rt (Bantam Sweet Dreams Romances)',
#  '101 Word Games for Students of English As a Second or Foreign Language (Resource Books for Teachers of Young Students)',
#  '101 cuentos clÃ¡sicos de la China',
#  '101 expÃ?Â©riences de philosophie quotidienne',
#  '101 uses for an unused home computer',
#  '102 1/2 Uses for an Extraterrestrial',
#  '102 Animal Jokes',
#  '102 Creepy, Crawly Bug Jokes',
#  '102 Dalmatians',
#  '102 Goofy Jokes',
#  '102 Haunted House Jokes',
#  '102 Out-Of-This-World Jokes',
#  '102 Questions Children Ask about the Bible (Questions Children Ask)',
#  '102 School Cafeteria Jokes',
#  '102 School Jokes',
#  '102 Wacky Monster Jokes',
#  '102 Wild and Wacky Jokes',
#  '103 Hikes: In Southwestern British Columbia',
#  '103 Questions Children Ask about Right from Wrong (Questions Children Ask)',
#  '104 Activities That Build: Self-esteem, Teamwork, Communication, Anger Management, Self-discovery, and Coping Skills',
#  '1066 &amp; All That: A Memorable History of England',
#  '1066: The Year of the Conquest',
#  '107 Questions Children Ask about Prayer (Questions Children Ask)',
#  '10th Grade : A Novel',
#  '10th Grade: A Novel',
#  '10th Kingdom',
#  '11 : 11: Inside the Doorway',
#  '11 Edward Street',
#  '11 Eleven: Witnessing the World Trade Center 1974-2001',
#  '11 Harrow House',
#  '11 Harrowhouse',
#  "11 Septembre 2001 : L'effroyable imposture",
#  '11 Settembre. LA Ragioni Di Chi',
#  '110 Shanghai Road',
#  '110%: 110 Strategies for Feeling Great Every Day',
#  '110. street-eko geltokia (Literatura beltza)',
#  '117 Days Adrift (World of Cruising)',
#  '1185 Park Avenue',
#  '1185 Park Avenue: A Memoir',
#  '119 Years of the Atlantic',
#  '11th Hour',
#  '12 Again',
#  '12 Days in Ghana: Reunions, Revelations &amp; Reflections',
#  '12 Days on the Road',
#  '12 Days on the Road: The Sex Pistols and America',
#  '12 Gothic Tales (Oxford Twelves)',
#  '12 Monkeys: A Novel',
#  '12 Mystery Stories (Oxford Twelves)',
#  '12 Philippine Women Writers (Philippine writers series)',
#  '12 Simple Secrets of Happiness at Work: Finding Fulfillment, Reaping Rewards',
#  '12 Simple Secrets of Happiness in a Topsy-Turvy World (12 Simple Secrets)',
#  '12 Simple Secrets of Happiness: Finding Joy in Everyday Relationships',
#  '12 Simple Steps To A Winning Marketing Plan',
#  '12 Step Prayer Book (Lakeside Meditation)',
#  '12 Steps and 12 Traditions',
#  '12 Steps to Living Without Fear',
#  '12 Steps to Raw Foods: How to End Your Addiction to Cooked Food',
#  '12 Steps: A Spiritual Journey (Tools for Recovery)',
#  '12 Stories',
#  '12 Stories for Late at Night',
#  '12 Victorian Ghost Stories',
#  '12 steps to living without fear',
#  '1215 : The Year of Magna Carta',
#  '122 Minutes a Month to Greater Profits',
#  '123 (The Anne Geddes Collection)',
#  '123 Slide and See',
#  '125 Brain Games for Babies',
#  '125 Brain Games for Toddlers and Twos: Simple Games to Promote Early Brain Development (125 Brain Games)',
#  '125 Cookies to Bake, Nibble, and Savor',
#  '125 Most Asked Questions About Cats (And the Answers)',
#  '125th Anniversary Commemorative Cookbook (Pennsylvania State Grange)',
#  '128 Ways to Say \\I Love You\\" to Your Cat"',
#  '12TH NIGHT',
#  '13',
#  '13 99 Euros',
#  '13 Cent Killers : The 5th Marine Snipers in Vietnam',
#  '13 Fatal Errors Managers Make and How You Can Avoid Them',
#  '13 Fatal Errors Managers Make, and How You Can Avoid Them',
#  '13 French Street and the Red Scarf',
#  '13 Ghosts: Strange But True Ghost Stories',
#  '13 Ghosts: Strange but True Stories',
#  '13 Going on 30',
#  '13 Murder Mysteries (Point Crime S.)',
#  '13 Royal Street (Silhoutte Intimate Moments, No 7447)',
#  '13 Scary Ghost Stories',
#  '13 Secrets for Speaking Fluent Japanese',
#  '13 Short Detective Novels',
#  '13 Short Espionage Novels',
#  "13 To 19: A Parent's Guide to Understanding the Teenage Years",
#  '13 [i.e. Dreizehn] unerwÃ¼nschte Reportagen: + Anhang, Verbotene AufrÃ¼stung, Giftgas fÃ¼r die Bundeswehr (Rororo Sachbuch)',
#  '131 Christians Everyone Should Know (Holman Reference)',
#  '13th Gen: Abort, Retry, Ignore, Fail?',
#  '13th Valley',
#  '14 Peck Slip',
#  '14 Valentine Place (Harlequin Superromance, No. 1035)',
#  '14 Vicious Valentines',
#  '14,000 Quips and Quotes for Writers and Speakers',
#  '14,000 Things to Be Happy About',
#  '14.99 Ã?Â?',
#  '140 neue Tipps fÃ?Â¼r tolle Chefs... ...und solche, die es werden wollen.',
#  '1421 : The Year China Discovered America',
#  '1421 The Year China Discovered America',
#  '1421. Als China die Welt entdeckte.',
#  '1421: The Year China Discovered America',
#  '147 Fun Things to do in Houston (5th Edition)',
#  '1492',
#  '15 Days of Prayer With Saint Faustina Kowalska',
#  "15 Houseplants Even You Can't Kill",
#  '15 Minute Devotions for Couples',
#  '15 Minute Family Traditions &amp; Memories',
#  '15 Minute Pilates: Body Maintenance to Make You Longer, Leaner and Stronger',
#  '15 Minutes Alone With God',
#  '15 Minutes of Peace With God',
#  "15 Months In Sog: A Warrior's Tour",
#  '15-Minute Low-Carb Recipes: Instant Recipes for Dinners, Desserts, and More',
#  '150 Most-Asked Questions About Menopause: What Women Really Want to Know',
#  '150 Solitaire Games',
#  '150 Vegan Favorites: Fresh, Easy, and Incredibly Delicious Recipes You Can Enjoy Every Day',
#  '158 POUND MARRIAGE',
#  '1587, A Year of No Significance',
#  '159 Celtic Designs (Dover Pictorial Archive)',
#  '16 Lighthouse Road',
#  '16 Uhr 50 ab Paddington.',
#  '1600 BÃ?Â¤uche.',
#  '1600 Ventres',
#  '1632 (Assiti Shards (Hardcover))',
#  '1632 (Assiti Shards (Paperback))',
#  '1633',
#  '1634 : The Galileo Affair (The Ring of Fire)',
#  '168/BUSINESS/ANYONE/',
#  '17 Lies That Are Holding You Back and the Truth That Will Set You Free',
#  '17 Secrets of the Master Prospectors',
#  '1700',
#  '1700: Scenes from London Life',
#  '175 Amazing Nature Experiments',
#  '175 Easy-To-Do Everyday  Crafts',
#  '175 Easy-To-Do Halloween Crafts',
#  '175 Easy-To-Do Thanksgiving Crafts (Creative Uses for Recyclables)',
#  '175 More Science Experiments to Amuse and Amaze Your Friends',
#  '1768 Encyclopaedia Britannica Replica: Add This Classic to Your Library Collection',
#  '1776: A Musical Play (Penguin Plays)',
#  '1776: Son of Liberty, Young Founders 3',
#  '1788: Comprising A narrative of the expedition to Botany Bay and A complete account of the settlement at Port Jackson',
#  '18 Best Stories by Edgar Allan Poe',
#  '18 WHEELS OF JUSTICE',
#  '18 Wheels of Justice',
#  '180 Days of Character',
#  '180 Degree Murder',
#  '1812',
#  '1812 (The American Story)',
#  '1846: Portrait of the Nation',
#  '1848, die ungewollte Revolution: Die revolutionÃ¤ren Bewegungen in Europa 1830-1849',
#  '1848: The Revolutionary Tide in Europe (Revolutions in the Modern World)',
#  '1870 Not With Our Blood (Young Founders Series)',
#  '1876',
#  '1876 (American Chronicle)',
#  '1876 a Novel',
#  '1876: A novel',
#  '1896 Boston Cooking-School Cookbook',
#  '1898: The Birth of the American Century',
#  '18Mm Blues',
#  '18th Century Lovers: A Book of Days',
#  '19 Purchase St.',
#  '19 Purchase Street',
#  '19 gifts of the spirit: Which do you have? Are you using them? (An input book)',
#  '1900 House',
#  '1901: A Novel',
#  '1912 Facts about Titanic',
#  '1915 the Death of Innocence',
#  '1916',
#  '1916: A Novel of the Irish Rebellion (Irish Century)',
#  '1919: Volume Two of the U.S.A. Trilogy',
#  '1921 : The Great Novel of the Irish Civil War (Irish Century)',
#  '1929',
#  '1933 WAS BAD YEAR',
#  '1939',
#  '1945 (Wing Commander)',
#  '1949 : A Novel of the Irish Free State (Irish Century)',
#  '1950: Crossroads of American Religious Life',
#  '1953: Chronicle of a Birth Foretold',
#  '1956 and all that: A memorable history of England since the war to end all wars (Two)',
#  '1959: A Novel',
#  '1968',
#  '1968 : The Year That Rocked the World',
#  '1968 In America: Music, Politics, Chaos, Counterculture and the Shaping of a Generation',
#  '1968 In America: Music, Politics, Chaos, Counterculture, and the Shaping of a Generation',
#  '1979.',
#  '1981 Guide to Coupons and Refunds',
#  '1984',
#  '1984 ( Neunzehnhundertvierundachtzig). JubilÃ?Â¤umsausgabe. Roman.',
#  '1984 (Cliffs Notes)',
#  "1984 (Everyman's Library)",
#  '1984 (Signet Classics (Paperback))',
#  '1984 (Spanish Language Edition)',
#  '1984 : a novel',
#  '1984 and Beyond',
#  '1984.',
#  '1984: Spring a Choice of Futures',
#  '1984: Spring: A Choice of Futures',
#  '1985: A Historical Report (Hong Kong 2036 from the Hungarian)',
#  '1987 What Color is Your Parachute?',
#  '1988',
#  '1988 Baseball Cards 120 Of T H',
#  '1988 South American Handbook (Footprint South American Handbook)',
#  '1989 Guinness Book of World Records (Guinness Book of World Records, 27th ed)',
#  '1989 Ireland',
#  '199 Great Home Businesses You Can Start (And Succeed in for Under $1,000)',
#  '199 Things to Do Over Summer Vacation',
#  "1990's Handbook: Modern Background for Cthulhu",
#  '1993 Yearbook of Astronomy',
#  "1994 Novel &amp; Short Story Writer's Market",
#  '1995 Information Please Sports Alman',
#  "1996 Poet's Market (Poet's Market, 1996)",
#  '1996-97 Texas Almanac and State Industrial Guide (Paper)',
#  "1997 Artist's &amp; Graphic Designer's Market (Artist's &amp; Graphic Designer's Market, 1997)",
#  '1997 Cancer June 21-July 20: Day-By-Day Horoscope',
#  "1997 Children's Writer's &amp; Illustrator's Market (Children's Writer's &amp; Illustrator's Market, 1997)",
#  "1997 Poet's Market (Poet's Market, 1997)",
#  "1998 Artist's &amp; Graphic Designer's Market (Artist's &amp; Graphic Designer's Market, 1998)",
#  "1998 Children's Writer's &amp; Illustrator's Market (Children's Writer's &amp; Illustrator's Market, 1998)",
#  '1998 Handbook of United States Coins: With Premium List (55th ed)',
#  '1998 Information Please Almanac (Serial)',
#  "1998 Novel &amp; Short Story Writer's Market (Novel &amp; Short Story Writer's Market, 1998)",
#  "1998 Poet's Market (Poet's Market, 1998)",
#  "1998 Writer's Market: Where &amp; How to Sell What You Write (Annual)",
#  '1999 (Thorndike Large Print Christian Fiction)',
#  "1999 Children's Writer's &amp; Illustrator's Market (Children's Writer's &amp; Illustrator's Market, 1999)",
#  '1999 Entertainment Weekly Yearbook (Entertainment Weekly Yearbook)',
#  '1999 Guide to Literary Agents: 500 Agents Who Sell What You Write (Guide to Literary Agents)',
#  "1999 Novel &amp; Short Story Writer's Market (Novel and Short Story Writer's Market)",
#  "1999 Poet's Market (Poet's Market, 1999)",
#  "1999 Writer's Market (Annual)",
#  '19th Precinct',
#  '1ST AMONG EQUALS',
#  '1ST AMONG EQUALS X',
#  '1ST BORN',
#  '1ST MAN THEN ADAM',
#  '1st Corinthians (Enduring Word Commentary)',
#  '1st Culprit',
#  '1st Treasury of Herman (Andrews &amp; McMeel Treasury Series)',
#  '1st to Die',
#  '1st to Die British Edition',
#  '1st to Die: A Novel',
#  '2 Doz Red Roses',
#  '2 Eyes a Nose and a Mouth',
#  '2 FOR TEXAS',
#  '2 Novels:  A Fine and Private Place &amp; The Madman Theory',
#  '2 Of Kind',
#  '2 Old Women',
#  '2 Sweet 2 B 4-Gotten (Friends 4-Ever, No 3)',
#  '2 YOUNG 2 GO 4 BOYS',
#  '2 Years Without Sleep: Working Moms Talk About Having a Baby and a Job',
#  '2 minutes a day for a greener planet',
#  '2,000 Sports Quips and Quotes',
#  '2,001 Things to Do Before You Die',
#  '2,002 Ways To Cheer Yourself Up',
#  '2,100 Victorian Monograms (Dover Pictorial Archive Series)',
#  '2,715 One-Line Quotations',
#  '2-In-1: The Instant Cholesterol and Fat Control System',
#  '20 Holy Hours:',
#  '20 Hot Potatoes Christians Are Afraid To Touch',
#  '20 Hot Potatoes Christians Are Afraid to Touch',
#  '20 Jahre 40 bleiben. Jung und schÃ?Â¶n in den besten Jahren.',
#  '20 Master Plots (And How to Build Them)',
#  '20 Master Plots: And How to Build Them',
#  "20 Most Asked Questions About the Amish and Mennonites (People's Place Book, No 1)",
#  '20 Poemas De Amor Y Una Cancion Deseperada/20 Poems Desperate Song',
#  '20 Secrets to Money and Independence: A Guide to Independence, Economic Empowerment, and Self-Awareness',
#  '20 Teachable Virtues: Practical Ways to Pass on Lessons of Virtue and Character to Your Children',
#  '20 UNDER 30',
#  '20 Years of Censored News',
#  "20 Years of Rolling Stone: What a Long, Strange Trip It's Been",
#  '20 Years of the Problem Page (Vol. 2)',
#  "20,000 Alarms: The Memoirs of New York's Most Decorated Fireman",
#  '20,000 Baseball Cards Under the Sea (Step-Into-Reading, Step 4)',
#  '20,000 Leagues Under the Sea',
#  '20,000 Leagues Under the Sea (American Short Stories)',
#  '20,000 Leagues Under the Sea (Bantam Classics)',
#  '20,000 Leagues Under the Sea (Great Illustrated Classics)',
#  '20,000 Leagues Under the Sea (Scholastic Classics)',
#  '20,000 Leagues Under the Sea (Step Into Classics)',
#  '20,000 Leagues Under the Sea (Treasury of Illustrated Classics)',
#  '20,000 Leagues Under the Sea (Wordsworth Collection)',
#  '20,000 Leagues Under the Sea / By Jules',
#  "20,000 Leagues Under the Sea: The Young Collector's Illustrated Classics/Ages 8-12",
#  '20,000 Leagues Under the Seas',
#  '20,000 Leaks Under the Sea (A Golden Sight and Sound Book)',
#  '20,000 Men and Me',
#  "20,000 Secrets of Tea: The Most Effective Ways to Benefit from Nature's Healing Herbs",
#  '20,000 words',
#  '20,001 Names For Baby : Revised and Updated',
#  '20,001 Names for Baby',
#  '20-Minute Cookbook: 50 Delicious, Quick and Healthy Recipes (Step-By-Step)',
#  '20-Minute Crafts',
#  '20-Minute Retreats: Revive Your Spirit in Just Minutes a Day With Simple Self-Led Practices',
#  '20-Minute Yoga Workouts',
#  "20/20 Hindsight: From Starting Up to Successful Entrepreneur, by Those Who'Ve Been There (Virgin Business Guides)",
#  '20/20 Vision',
#  '200 Beats Per Minute',
#  '200 Classic Chess Puzzles',
#  '200 Great Painting Ideas for Artists',
#  '200 Small House Plans: Selected Designs Under 2,500 Square Feet (Blue Ribbon Designer Series)',
#  '200 Tips for Growing Beautiful Roses',
#  "200 Ways to Raise a Girl's Self-Esteem: An Indispensable Guide for Parents, Teachers &amp; Other Concerned Caregivers",
#  '200 Years of Great American Short Stories',
#  '200% Wife (That Special Woman!/Stanford Sisters) (Silhouette Special Edition)',
#  '2000 A.D.: Are You Ready? : How New Technologies and Lightning-Fast Changes Are Opening the Door for Satan and His Plan for the End of the World',
#  "2000 Artist's &amp; Graphic Designer's Market (Artist's &amp; Graphic Designer's Market, 2000)",
#  '2000 INSULTS',
#  '2000 Kisses',
#  '2000 MORE INSULTS',
#  "2000 Photographer's Market (Photographer's Market, 2000)",
#  "2000 Poet's Market (Poet's Market, 2000)",
#  '2000 Scrapbook Hall of Fame',
#  '2000 Taste Of Home Annual Recipes',
#  "2000 Taste of Home's Quick Cooking Annual Recipes",
#  '2000 What Color is Your Parachute',
#  '2000 Year Old Man In the Year the B',
#  '20000 Leagues Under the Sea',
#  '20000 Years of Fashion',
#  '20000 lieues sous les mers',
#  '2001',
#  '2001 - A Space Odyssey',
#  "2001 - L'odyssee De L'espace",
#  '2001 A Space Odyssey',
#  '2001 Cross-Stitch Designs: The Essential Reference Book',
#  '2001 Formula One Annual',
#  '2001 French and English Idioms: 2001 Idiotismes Francais Et Anglais',
#  '2001 Japanese and English Idioms (2001 Idioms Series)',
#  "2001 Lippincott's Nursing Drug Guide (Book with Mini CD-ROM for Windows &amp; Macintosh)",
#  "2001 Novel &amp; Short Story Writer's Market (Novel &amp; Short Story Writer's Market, 2001)",
#  "2001 Poet's Market (Poet's Market, 2001)",
#  '2001 Spanish and English Idioms, 2001 Modismos Espa~Noles E Ingleses',
#  '2001 Spanish and English Idioms/2001 Modismos Espanoles E Ingleses: 2001 Modismos Espanoles E Ingleses',
#  "2001 Writer's Market: The Internet Edition",
#  '2001 a Space Odyssey',
#  '2001. Odyssee im Weltraum.',
#  '2001: A Space Odssey',
#  '2001: A Space Odyssey',
#  '2001: A Space Odyssey : a Novel by Arthur C. Clarke',
#  '2001: On the Edge of Eternity',
#  '2001: Una Odisea Espacial',
#  '2002 American Guide to U.S. Coins : The Most Up-to-Date Coin Prices Available (American Guide to Us Coins)',
#  '2002 Days &amp; Nights of Sex',
#  '2002 ESPN Information Please Sports Almanac: The Definitive Sports Reference Book',
#  "2002 Novel &amp; Short Story Writers Market (Novel and Short Story Writer's Market)",
#  '2002 Official Rules of Major League Baseball',
#  "2002 Photographer's Market (Photographer's Market, 2002)",
#  '2002 Romantic Ideas: Special Moments You Can Share With the One You Love',
#  '2002 Things to Do on a Date: From Fun, Sometimes Silly, Romantic, to the Unique (2002)',
#  '2002 Trailer Life Directory: Campgrounds, RV Parks, and Services',
#  '2002 Ways To Say \\I Love You\\""',
#  '2002 World Press Photo (World Press Photo, 2002)',
#  "2002 Writer's Market Online",
#  "2002 Writer's Market: 8,000 Editors Who Buy What You Write",
#  '2003 Guide to Literary Agents: 600+ Agents Who Sell What You Write (Guide to Literary Agents, 2003)',
#  '2003 Handbook of United States Coins: With Premium List (Handbook of United States Coins)',
#  "2003 Novel &amp; Short Story Writer's Market",
#  "2003 Poet's Market (Poet's Market, 2003)",
#  "2004 Artist's &amp; Graphic Designer's Market (Artist's &amp; Graphic Designer's Market, 2004)",
#  "2004 Children's Writer's &amp; Illustrator's Market (Children's Writer's &amp; Illustrator's Market, 2004)",
#  '2004 Kirigami Fold &amp; Cut-A-Day Calendar',
#  "2004 Photographer's Market (Photographer's Market, 2004)",
#  '2006: The Chautauqua Rising',
#  '2007-Eleven: And Other American Comedies',
#  '201 French Verbs Fully Conjugated in All the Tenses, Alphabetically Arranged.',
#  '201 Great Ideas for Your Small Business',
#  '201 Portuguese Verbs Fully Conjugated in All the Tenses, Alphabetically Arranged',
#  '201 Ways to Deal With Difficult People (Quick-Tip Survival Guides)',
#  '2010 Odisea 2',
#  '2010: Odisea DOS',
#  '2010: Odyssey Two',
#  '2020 VISION',
#  '2020 Vision',
#  '2024',
#  '2024: A Graphic Novel',
#  '203 Home Based Businesses That Will Make',
#  '203 Home-Based Businesses That Will Make You Rich : The Complete Guide to Financing and Running a Fabulously Successful Home-Based Business',
#  '203 Ways to Be Supremely Successful in the New World of Selling',
#  '203 Ways to Drive a Man Wild in Bed',
#  '204 Rosewood Lane',
#  '2041: Twelve Short Stories About the Future by Top Science Fiction Writers',
#  '2061. Odyssee III. Roman.',
#  '2061: Odyssey Three',
#  '2095 (Time Warp Trio)',
#  '2095/Your Mother Was a Neanderthal Flip Book: Your Mother Was a Neanderthal (Scieszka, Jon. Time Warp Trio.)',
#  '20th Century Art',
#  '20th Century Art Museum Ludwig Cologne (Klotz)',
#  '20th Century Day By Day: The Ultimate Record of Our Times',
#  '20th Century Design',
#  '20th Century Icons-Gay',
#  '20th Century Photography Museum Ludwig Cologne (Klotz)',
#  '20th Century Pop Culture',
#  '20th-century poetry &amp; poetics',
#  '21 Days to a Better Quiet Time with God',
#  "21 Dog Years : A Cube Dweller's Tale",
#  '21 Dog Years : Doing Time @ Amazon.com',
#  '21 Great Stories',
#  '21 Sugar Street',
#  '2107 Curious Word Origins, Sayings and Expressions from White Elephants to Song Dance',
#  '2150 Ad',
#  '2150, A. D.',
#  '2182 Kilohertz',
#  '2182 kHz',
#  '2194 days of war: An illustrated chronology of the Second World War with 620 illustrations and 84 maps',
#  '21st Century Beauty Bible',
#  '21st Century Blues',
#  '21st Century Dictionary of Computer Terms (21st Century Reference)',
#  '21st Century Dictionary of Quotations (21st Century Reference)',
#  "21st Century Etiquette: Charlotte Ford's Guide to Manners for the Modern Age",
#  '21st Century German-English English-German Dictionary (21st Century Reference)',
#  '21st Century Guide to Improving Your Writing (21st Century Reference)',
#  '21st Century Guide to Increasing Your Reading Speed (21st Century Reference)',
#  '21st Century Manual of Style',
#  "21st Century Robert's Rules of Order (21st Century Reference)",
#  "21st Century Wicca: A Young Witch's Guide to Living the Magical Life (Citadel Library of the Mystic Arts)",
#  '22 Days in Great Britain: The Itinerary Planner',
#  '22 Indigo Place',
#  '22 days in Norway, Sweden &amp; Denmark: The itinerary planner (JMP travel)',
#  '2201 Fascinating Facts',
#  ...]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### TODO:
# * Use the `describe` and `info` methods on each of your dataframes.
# * Check the `dtypes` for the columns in each dataframe.
# * Check for missing values in each dataframe
# * Check for any other operations commonly used during EDA and perform it here

# %% [markdown]
# ## Fact-Finding

# %% [markdown]
# You may need to apply the `groupby` method here. Here's a great introduction: [Pandas GroupBy: Your Guide to Grouping Data in Python](https://realpython.com/pandas-groupby/).
# ### TODO:
# * Group the `ratings` dataframe by `User-ID` and check the `average` rating by user.
# * Group the `ratings` dataframe by `ISBN` and check the `average` rating each book has gotten.
# * Create a `Series` containing the number of books each user has read
# * Who are the top 10 most rated authors?
# * Who are the top 10 highest rated authors?

# %% [markdown]
# ## Engineering

# %% [markdown]
# ### TODO:
# * Apply the `to_datetime` method to the `Year-of-Publication` `inplace`.
# * Use the `drop` method to drop all the `Image` columns in the `books` dataframe.
# * Read this article - [How to Split String Column in Pandas into Multiple Columns](https://www.statology.org/pandas-split-column/) then apply the method to split the `location` column into three columns `city`, `state`, `country`.
# * Which other `str` methods are available in pandas? Try out one or two others.
# * Merge the `ratings` and `books` dataframe into one dataframe named `books_and_ratings`
# * Merge the `books_and_ratings` dataset and the `users` dataframe into a dataframe named `user_preferences`

# %% [markdown]
# ## Querying and Indexing

# %% [markdown]
# Here's a useful article:
# * [The Unreasonable Effectiveness of Method Chaining in Pandas](https://towardsdatascience.com/the-unreasonable-effectiveness-of-method-chaining-in-pandas-15c2109e3c69)

# %% [markdown]
# ### TODO:
# * Use the `query` method to return rows from the `user_preferences` dataframe where `User-ID` is equal to `276822`
# * Repeat the same operation as before but this time return rows where `ISBN` is equal to `0345260317`
# * Return rows where the `ISBN` is equal to `0345260317` and `Book-Rating` is greater than 0.
# * Repeat all the operations performed above using the `loc` method rather than `query`
# * Time the operation of both methods (See [Profiling and Timing Code](https://jakevdp.github.io/PythonDataScienceHandbook/01.07-timing-and-profiling.html)). Which is faster?
# * Use the `to_dict` method to convert the output of query to dictionary.
# * Write a function that takes in a `dataframe` and a `user_id` and returns a dictionary of rows with matching user ids. Test your function using the `user_preferences` dataframe and any user id in the data.

# %% [markdown]
# ### Hierarchical Indexing

# %% [markdown]
# Study the [Hierarchical Indexing](https://jakevdp.github.io/PythonDataScienceHandbook/03.05-hierarchical-indexing.html) chapter from Python Data Science Handbook.

# %% [markdown]
# ### TODO
# * Include 3 or 4 of your observations in the `Comments` below after exploring the dataset

# %% [markdown]
# ### Comments
# *
